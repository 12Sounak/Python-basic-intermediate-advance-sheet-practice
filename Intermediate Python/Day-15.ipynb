# %% [markdown]
# Given the side length x find the area of a hexagon.<br>
# ![image.png](attachment:image.png)
# <br>
# Examples <br>
# area_of_hexagon(1) ➞ 2.6  <br>
# area_of_hexagon(2) ➞ 10.4 <br>
# area_of_hexagon(3) ➞ 23.4 <br>

# %%
def area(s):
    a = round(((3*1.7320*s*s)/2),ndigit=1)
    r = format(a,".2f")
    print(r)
    print(a)

s = int(input("Enter the side :"))
area(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       5     print(a)
#       7 s = int(input("Enter the side :"))
# ----> 8 area(s)
#
# Cell In[8], line 2, in area(s)
#       1 def area(s):
# ----> 2     a = round(((3*1.7320*s*s)/2),ndigit=1)
#       3     r = format(a,".2f")
#       4     print(r)
#
# TypeError: 'ndigit' is an invalid keyword argument for round()

# %%
def myfun(s):
    area=round((1.5)*(3**(1/2))*(s**2),ndigits=1)
    return area

# i = float(input("Enter the side :"))
myfun(1)
# print(a)
# Out:
# 2.6

# %%
"""
Question 22. 
Create a function that returns a base-2 (binary) representation of a base-10 
(decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10) 
010101001(2) = 1 + 8 + 32 + 128. 
Going from right to left, the value of the most right bit is 1, now from that every bit to the left 
will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1). 
Examples: 
binary(1) ➞ "1" 
1*1 = 1 
binary(5) ➞ "101" 
11 + 14 = 5 
binary(10) ➞ "1010" 
12 + 18 = 10     
"""

# sam solution
def myfun(n):
    x=n
    l=list()
    while x>=1:
        l.append(str(x%2))
        x=x//2
    l=l[::-1]
    print("".join(l))

myfun(10)
# Out:
# 1010

# %%
a = 5
b = 5/2
c = 5%2
print(b)
print(c)
# Out:
# 2.5
# 1

# %%
def decimal_to_binary(a):
    n = len(a)
    for i in a:
        a = 
n = int(input("Enter the decimal number :"))
decimal_to_binary(n)

# %%
a = 34123
n = len(a)
for i in range(0,n):
    print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 a = 34123
# ----> 2 for i in a:
#       3     print(i)
#
# TypeError: 'int' object is not iterable

# %%
while num != 0:
    digit = num % 10
    # reversed_num = reversed_num * 10 + digit
    num //= 10

# %%
52%2
# Out:
# 0

# %%
53/2
# Out:
# 26.5

# %%
def decimal_to_binary(a):
    l=[]
    for i in range(1,a):
        if a%i==0:
            l.append(0)
        else:
            l.append(1)
    print(l)
n = int(input("Enter the decimal number :"))
decimal_to_binary(n)
# Out:
# [0, 0, 1, 1, 0, 1, 1, 1, 1]

# %%
""" 
Question 23.  
Create a function that takes three arguments a, b, c and returns the sum of the 
numbers that are evenly divided by c from the range a, b inclusive. 
Examples 
evenly_divisible(1, 10, 20) ➞ 0 
# No number between 1 and 10 can be evenly divided by 20. 
evenly_divisible(1, 10, 2) ➞ 30 
# 2 + 4 + 6 + 8 + 10 = 30 
evenly_divisible(1, 10, 3) ➞ 18 
# 3 + 6 + 9 = 18  
""" 

def evenly_divisible(a,b,c):
    sum = 0
    for i in range(a,b+1):
        if (i%c==0):
            z = i//c
            sum = sum + i
    print(sum)

evenly_divisible(1,10,3)
# Out:
# 0
